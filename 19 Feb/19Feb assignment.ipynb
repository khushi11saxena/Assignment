# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a micro-framework, meaning that it’s designed to perform a more limited role than a full-stack framework like Django.
#  Advantages :
#  Easier to develop,More Flexible,

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/") #decorator
def hello_world():
    return "<h1>Hello World!</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.29.77:5000
# Press CTRL+C to quit
# 192.168.29.77 - - [03/Mar/2023 18:20:37] "GET / HTTP/1.1" 200 -
# 192.168.29.77 - - [03/Mar/2023 18:20:37] "GET /favicon.ico HTTP/1.1" 404 -
# 192.168.29.77 - - [03/Mar/2023 18:22:18] "GET / HTTP/1.1" 200 -

# %%
from IPython.display import Image
Image(filename='Screenshot 2023-03-03 182108.png')

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing is used to map the specific URL with the associated function that is intended to perform some task. The routing technique helps a user remember application URLs and is useful to access the desired page directly without having to navigate from the home page. The route () decorator in Flask is used to bind URL to a function.
#
# The primary purpose of App Routing in Flask is to provide a way to handle incoming HTTP requests and map them to specific functions that will generate an appropriate response. This allows developers to create dynamic web applications that can respond to user input and provide customized content based on the user's actions.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/welcome") #decorator
def welcome():
    return "<h1>Welcome to ABC Corporation</h1>"

@app.route("/") 
def details():
    return "<h1>Compay Name : ABC Corporation <br>Location: India <br>Contact Detail: 999-999-9999</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.29.77:5000
# Press CTRL+C to quit
# 192.168.29.77 - - [03/Mar/2023 19:02:44] "GET / HTTP/1.1" 200 -
# 192.168.29.77 - - [03/Mar/2023 19:03:29] "GET /welcome HTTP/1.1" 200 -

# %%
Image(filename='Screenshot 2023-03-03 190259.png')

# %%
Image(filename='Screenshot 2023-03-03 190333.png')

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.
#
# In Flask, the url_for() function is used for URL building. The url_for() function generates a URL based on the name of the function that handles the desired endpoint, and any arguments that the endpoint requires.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def index():
    return 'This is the homepage'

@app.route('/user/<username>')
def user_profile(username):
    return f'This is the profile page for {username}'

with app.test_request_context():
    print(url_for('index'))
    print(url_for('user_profile', username='Khushi'))

if __name__ == '__main__':
    app.run(host="0.0.0.0", port=5000)
# Out:
# /
# /user/Khushi
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.29.77:5000
# Press CTRL+C to quit
# 192.168.29.77 - - [03/Mar/2023 19:10:28] "GET / HTTP/1.1" 200 -
# 192.168.29.77 - - [03/Mar/2023 19:11:02] "GET / HTTP/1.1" 200 -
# ()
